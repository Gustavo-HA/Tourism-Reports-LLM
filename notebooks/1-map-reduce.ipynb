# %%
import pandas as pd

# %%
data = pd.read_csv('../data/raw/reviews.csv')

# %%
data.loc[(data['Polarity'] == 3) & (data['Town'] == 'Tulum') & (data['Type'] == 'Hotel')].sample(20)['Review']
# Out:
# 141297    Diamante K tiene una buena cama, la habitación...
# 144717    El hotel la reserva se hizo con una fiesta de ...
# 7213      Es la primera vez que visitamos el adonis y me...
# 165803    Mi encabezado dice todo. Las cosas buenas aquí...
# 119131    Fue una experiencia muy mala lo que aparece en...
# 200226    son pequeñas cabañas en la playa de tulum, la ...
# 10160     Conseguimos la mejor habitación con la mejor v...
# 171569    Nos dijeron sobre la instalación de chime wind...
# 149019    Un gran lugar para alojarse, las habitaciones ...
# 153242    Tuve la oportunidad de viajar hace 3 años y la...
# 6132      Sueños puede ser una pesadilla ... Este lugar ...
# 123789    Me alojé en el complejo para un retiro de yoga...
# 105153    Pésimo servicio de las diferentes áreas con ex...
# 127036    El hotel es mágico gracias a sus instalaciones...
# 83305     Tulum es una gran escapada de invierno. Este h...
# 190179    Es un lugar hermoso pero honestamente muy sobr...
# ...
