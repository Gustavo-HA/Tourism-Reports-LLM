# %%
import pandas as pd

# %%
data = pd.read_csv('../data/raw/reviews.csv')

# %%
data.loc[(data['Polarity'] == 1) & (data['Town'] == 'Tulum') & (data['Type'] == 'Hotel')].sample(20)['Review']
# Out:
# 71713     Te dirán que se cargará una cantidad, pero que...
# 63537     Teniendo la playa que tienen, no es suficiente...
# 133502    Nunca me he sentido más insultado o violated e...
# 184406    WORST HOTEL IN TULUM: Este es el peor hotel qu...
# 61854     Si quieres una auténtica "volver a lo básico" ...
# 143629    Un hotel con personal muy amable pero no sé qu...
# 194949    Cancelaron la reserva 11 días antes de nuestro...
# 47683     Este lugar considera 3 estrellas- pero ¿cómo h...
# 82673     Nos habíamos tomado unas vacaciones durante el...
# 178835    Fue la peor experiencia de mi vida.la mayoria ...
# 80153     La revisión y fotos en la web increíble, sin e...
# 199643    México es mi lugar feliz. Mi esposo y yo hemos...
# 16869     El costo beneficio de este hotel no es el mejo...
# 141322    El hotel y los empleados son una maravilla. No...
# 34658     Mi hermana y yo nos alojamos aquí en 2012 juni...
# 22405     Fuimos a Dreams como amigos se casaban cerca, ...
# ...
